# %%
import IPython
IPython.version_info
# Out:
# (6, 2, 1, '')

# %%
# executes really fast
if False:
    pass

# %%
# takes several seconds
if False:




















































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































    pass
